# %%
import pandas as pd
import numpy as np

# %%
nba_df = pd.read_csv("nba.csv")
nba_df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba_df.columns[0]
# Out:
# 'Name'

# %%
for col in nba_df.columns:
    print(col)
# Out:
# Name
# Team
# Number
# Position
# Age
# Height
# Weight
# College
# Salary

# %%
# Adding new column to existing DF Method 1
# Dict with student data
student_data = {
    
    'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
    'Height': [170, 180, 165, 175], 
    'Qualification':['MSc', 'MA', 'MSc', 'MSc']
    
}

student_df = pd.DataFrame(student_data)

# add a new column by declaring a new list
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
favorite_food = ['Carrot', 'Apple', 'Strawberry', 'Tomato']
gpa = [3.6, 4.7, 2.2, 5.0]
nationality = ['India', 'Pakistan', 'Bhutan', 'Bangladesh']
has_driver_license=[True, True, False, True]
class_no = ['01A', '02A', '03A','01A']
weight_kg = [80,75,64,95] 
student_number = ['3487593', '2485943', '1231432', '2348982']

student_df['Student_address'] = address
student_df['Food'] = favorite_food
student_df['GPA'] = gpa
student_df['Nationality'] = nationality
student_df["Driver License"]=has_driver_license
student_df['Class_No'] = class_no
student_df['Student_Weight'] = weight_kg
student_df['Student_number'] = student_number


student_df
# Out:
#      Name  Height Qualification Student_address        Food  GPA Nationality  \
# 0     Jai     170           MSc           Delhi      Carrot  3.6       India
# 1  Princi     180            MA       Bangalore       Apple  4.7    Pakistan
# 2  Gaurav     165           MSc         Chennai  Strawberry  2.2      Bhutan
# 3    Anuj     175           MSc           Patna      Tomato  5.0  Bangladesh
#
#    Driver License Class_No  Student_Weight Student_number
# 0            True      01A              80        3487593
# 1            True      02A              75        2485943
# 2           False      03A              64        1231432
# 3            True      01A              95        2348982

# %%
student_df.insert(2, "Age", [21,23,24,22], True)
student_df
# Out:
#      Name  Height  Age Qualification Student_address        Food  GPA  \
# 0     Jai     170   21           MSc           Delhi      Carrot  3.6
# 1  Princi     180   23            MA       Bangalore       Apple  4.7
# 2  Gaurav     165   24           MSc         Chennai  Strawberry  2.2
# 3    Anuj     175   22           MSc           Patna      Tomato  5.0
#
#   Nationality  Driver License Class_No  Student_Weight Student_number
# 0       India            True      01A              80        3487593
# 1    Pakistan            True      02A              75        2485943
# 2      Bhutan           False      03A              64        1231432
# 3  Bangladesh            True      01A              95        2348982

# %%
student_df.insert(2, "Birth", [1999,1997,1996,2998], True)
student_df
# Out:
#      Name  Height  Birth  Age Qualification Student_address        Food  GPA  \
# 0     Jai     170   1999   21           MSc           Delhi      Carrot  3.6
# 1  Princi     180   1997   23            MA       Bangalore       Apple  4.7
# 2  Gaurav     165   1996   24           MSc         Chennai  Strawberry  2.2
# 3    Anuj     175   2998   22           MSc           Patna      Tomato  5.0
#
#   Nationality  Driver License Class_No  Student_Weight Student_number
# 0       India            True      01A              80        3487593
# 1    Pakistan            True      02A              75        2485943
# 2      Bhutan           False      03A              64        1231432
# 3  Bangladesh            True      01A              95        2348982

# %%
len(student_df)
# Out:
# 4

# %%
nba_df["Country"] = "CAN"

# %%
nba_df
# Out:
#               Name            Team Paying currecny  Number Position   Age  \
# 0    Avery Bradley  Boston Celtics         Dollars     0.0       PG  25.0
# 1      Jae Crowder  Boston Celtics         Dollars    99.0       SF  25.0
# 2     John Holland  Boston Celtics         Dollars    30.0       SG  27.0
# 3      R.J. Hunter  Boston Celtics         Dollars    28.0       SG  22.0
# 4    Jonas Jerebko  Boston Celtics         Dollars     8.0       PF  29.0
# ..             ...             ...             ...     ...      ...   ...
# 453   Shelvin Mack       Utah Jazz         Dollars     8.0       PG  26.0
# 454      Raul Neto       Utah Jazz         Dollars    25.0       PG  24.0
# 455   Tibor Pleiss       Utah Jazz         Dollars    21.0        C  26.0
# 456    Jeff Withey       Utah Jazz         Dollars    24.0        C  26.0
# 457            NaN             NaN         Dollars     NaN      NaN   NaN
#
#     Height  Weight            College     Salary Country
# ...

# %%
student_data

student_df = pd.DataFrame(student_data)

address = {
    "Delhi":"Jai",
    "Bangalore":"Princi",
    "Patna": "Gaurav",
    "Chennai": "Anuj"
}
age = {
    "1992":"Jai",
    "1986":"Princi",
    "1999": "Gaurav",
    "2001": "Anuj"
}

student_df["Address"] = address
student_df["Age"] = age

# %%
student_df
# Out:
#      Name  Height Qualification    Address   Age
# 0     Jai     170           MSc      Delhi  1992
# 1  Princi     180            MA  Bangalore  1986
# 2  Gaurav     165           MSc      Patna  1999
# 3    Anuj     175           MSc    Chennai  2001

# %%
nba_df2 = nba_df[nba_df.columns[1:4]]
nba_df3 = nba_df2.drop(labels="Paying currecny", axis=1, inplace=False)
nba_df3
# Out:
#                Team  Number
# 0    Boston Celtics     0.0
# 1    Boston Celtics    99.0
# 2    Boston Celtics    30.0
# 3    Boston Celtics    28.0
# 4    Boston Celtics     8.0
# ..              ...     ...
# 453       Utah Jazz     8.0
# 454       Utah Jazz    25.0
# 455       Utah Jazz    21.0
# 456       Utah Jazz    24.0
# 457             NaN     NaN
#
# [458 rows x 2 columns]

# %%
nba_df2
# Out:
#                Team Paying currecny  Number
# 0    Boston Celtics         Dollars     0.0
# 1    Boston Celtics         Dollars    99.0
# 2    Boston Celtics         Dollars    30.0
# 3    Boston Celtics         Dollars    28.0
# 4    Boston Celtics         Dollars     8.0
# ..              ...             ...     ...
# 453       Utah Jazz         Dollars     8.0
# 454       Utah Jazz         Dollars    25.0
# 455       Utah Jazz         Dollars    21.0
# 456       Utah Jazz         Dollars    24.0
# 457             NaN         Dollars     NaN
#
# [458 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-45cb35f957c7> in <module>
# ----> 1 nba_df.columns[20]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# -> 3930             return getitem(key)
#    3931
#    3932         if isinstance(key, slice):
#
# IndexError: index 20 is out of bounds for axis 0 with size 11
