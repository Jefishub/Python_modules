# %%
import pandas as pd
import numpy as np

# %%
nba_cf = pd.read_csv("nba.csv", skiprows=[1,2]) # sep, skiprows, skipfootre, nrows, encoding, usecols
nba_cf
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 1      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 2    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 3     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 4    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 451   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 452      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 453   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 454    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 455            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary
# 0    Boston University         NaN
# ...

# %%
nba_cf = pd.read_csv("nba.csv", nrows=20)
nba_cf
# Out:
#                        Name            Team  Number Position   Age Height  \
# 0             Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1               Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2              John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3               R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4             Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 5              Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9
# 6             Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8
# 7              Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0
# 8              Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2
# 9              Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# ...

# %%
nba_cf = pd.read_csv("nba.csv", usecols=["Name","Team"])
nba_cf
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
nba_cf = pd.read_csv("nba.csv", usecols=[0,1])
nba_cf
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
nba_cf = pd.read_csv("nba.csv", skipfooter=3, usecols=[0,1]) # sep, skiprows, skipfooter, nrows, encoding, usecols
nba_cf
# Out:
# C:\Users\Jefis\anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 450     Joe Ingles       Utah Jazz
# 451  Chris Johnson       Utah Jazz
# 452     Trey Lyles       Utah Jazz
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
#
# [455 rows x 2 columns]

# %% [markdown]
# nba_cf = pd.read_csv("nba.csv", skiprows=[]) # sep, skiprows, skipfootre, nrows, encoding, usecols
# nba_cf###

# %%
nba_cf = pd.read_csv("nba.csv", skiprows=[2],skip_blank_lines=False) # sep, skiprows, skipfooter, nrows, encoding, usecols
nba_cf
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 2      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 3    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 4     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 453      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 454   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 455    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 456            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary
# 0                Texas   7730337.0
# ...

# %%
nba_cf.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 2    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 3  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 4   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1  Boston University         NaN
# 2      Georgia State   1148640.0
# 3                NaN   5000000.0
# 4                NaN  12000000.0

# %%
nba_cf.head(20)
# Out:
#                        Name            Team  Number Position   Age Height  \
# 0             Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1              John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 2               R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 3             Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 4              Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9
# 5             Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8
# 6              Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0
# 7              Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2
# 8              Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4
# 9           Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 10            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# 11              Evan Turner  Boston Celtics    11.0       SG  27.0    6-7
# ...

# %%
nba_cf.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 452  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 453     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 454  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 455   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 456           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 452  2433333.0
# 453   900000.0
# 454  2900000.0
# 455   947276.0
# 456        NaN

# %%
nba_cf.tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 447  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 448     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 449      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 450   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 451      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 452    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 453       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 454    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 455     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
# 456             NaN        NaN     NaN      NaN   NaN    NaN     NaN
#
#       College      Salary
# 447    Butler  15409570.0
# 448      Duke   1348440.0
# 449       NaN   2050000.0
# 450    Dayton    981348.0
# 451  Kentucky   2239800.0
# 452    Butler   2433333.0
# ...
